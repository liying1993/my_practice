# %%
import pandas as pd
from bokeh.palettes import viridis

df = pd.read_csv('/Users/liying/Downloads/winemag-data_first150k.csv', index_col=0)
            
df.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
df.country.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                  US
# 1               Spain
# 2                  US
# 3                  US
# 4              France
# 5               Spain
# 6               Spain
# 7               Spain
# 8                  US
# 9                  US
# 10              Italy
# 11                 US
# 12                 US
# 13             France
# 14                 US
# 15                 US
# 16                 US
# 17              Spain
# 18             France
# 19                 US
# 20                 US
# 21              Spain
# 22              Spain
# 23                 US
# 24                 US
# 25        New Zealand
# 26                 US
# 27                 US
# 28                 US
# 29                 US
#              ...
# 150900          Chile
# 150901          Chile
# 150902          Chile
# 150903          Chile
# 150904          Chile
# 150905          Chile
# 150906         France
# 150907         France
# 150908         France
# 150909         France
# 150910         France
# 150911         France
# 150912         France
# 150913         France
# 150914             US
# 150915             US
# 150916             US
# 150917         France
# 150918         France
# 150919         France
# 150920          Italy
# 150921         France
# 150922          Italy
# 150923         France
# 150924         France
# 150925          Italy
# 150926         France
# 150927          Italy
# 150928         France
# 150929          Italy
# Name: country, Length: 150930, dtype: object>

# %%
df_Aus = df[df.country=="Australia"].copy()
df_Aus
# Out:
#           country                                        description  \
# 61      Australia  Moorooduc's estate Pinot Noir is a solid value...
# 631     Australia  Tim Knappstein's decision to focus on the Adel...
# 660     Australia  This crisp, delicate Pinot Noir should be cons...
# 825     Australia  The Dead Arm is always firmly structured, maki...
# 987     Australia  This is strongly marked by new oak on the nose...
# 1066    Australia  Hints of lemon curd and struck flint emerge fr...
# 2025    Australia  This medium-bodied Shiraz is refreshingly medi...
# 2028    Australia  From vines that were 79 years old when the fru...
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2325    Australia  Based in Clare Valley, Wakefield sources this ...
# 2379    Australia  This is ripe, rich and even a touch tannic—alm...
# 2398    Australia  This is deliberately picked early to preserve ...
# 2458    Australia  This is a top example of the classic Australia...
# 2617    Australia  Smoky and herbal upfront, this is a light-bodi...
# 2703    Australia  This is deliberately picked early to preserve ...
# 2973    Australia  The 2012 and 2013 vintages were both strong in...
# 2992    Australia  It's difficult to find $20 Pinot Noir this goo...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
#
# 149544   Semillon-Sauvignon Blanc       Simon Gilbert
# 149548         Cabernet Sauvignon            Climbing
# 149612                   Riesling       Jacob's Creek
# 149614                 Chardonnay           Lindemans
# 149621            Sauvignon Blanc      West Cape Howe
# 149632                 Chardonnay          White Knot
# 149639                 Chardonnay       Jacob's Creek
# 150434                 Chardonnay           Teal Lake
# 150468                     Shiraz           Teal Lake
# 150562                     Shiraz            Penfolds
# 150563                     Shiraz            Penfolds
# 150570         Cabernet Sauvignon            Penfolds
# 150571                 Chardonnay            Penfolds
# 150597         Cabernet Sauvignon            Penfolds
# 150607                     Shiraz            Penfolds
# 150621         Cabernet Sauvignon            Penfolds
# 150634                   Riesling            Penfolds
# 150650  Shiraz-Cabernet Sauvignon            Penfolds
# 150768  Shiraz-Cabernet Sauvignon       Jacob's Creek
# 150779                     Shiraz       Jacob's Creek
# 150786                 Chardonnay       Jacob's Creek
# 150801                 Chardonnay       Jacob's Creek
# 150810         Cabernet Sauvignon       Jacob's Creek
# 150819                 Chardonnay       Jacob's Creek
# 150854        Semillon-Chardonnay       Jacob's Creek
#
# [4957 rows x 10 columns]

# %%
df_Aus.describe()
# Out:
#             points        price
# count  4957.000000  4894.000000
# mean     87.892475    31.258480
# std       2.977779    39.008512
# min      80.000000     5.000000
# 25%      86.000000    15.000000
# 50%      88.000000    20.000000
# 75%      90.000000    34.000000
# max     100.000000   850.000000

# %%
df_Aus.isnull().any()
# Out:
# country        False
# description    False
# designation     True
# points         False
# price           True
# province       False
# region_1       False
# region_2        True
# variety        False
# winery         False
# dtype: bool

# %%
len(df_Aus[df_Aus.price.isnull()])
# Out:
# 63

# %%
len(df_Aus[df_Aus["price"].isnull()])
# Out:
# 63

# %%
df_Aus.values
# Out:
# array([['Australia',
#         "Moorooduc's estate Pinot Noir is a solid value among the boutique offerings from the Mornington Peninsula. There's a supple cushioning of flesh wrapped around a firm backbone of acid, while the flavors run from black cherry and mint through earthier notes of brown sugar and roasted parsnip. Drink now through 2020.",
#         nan, ..., nan, 'Pinot Noir', 'Moorooduc'],
#        ['Australia',
#         "Tim Knappstein's decision to focus on the Adelaide Hills bears fruit in this terrific-value Pinot Noir. The aromas and flavors are a colorful mélange of beets, black cherries and purple heirloom tomatoes, backed by a rich texture and a long velvety finish. Drink now until 2020.",
#         'The Dagger', ..., nan, 'Pinot Noir', 'Riposte'],
#        ['Australia',
#         'This crisp, delicate Pinot Noir should be consumed over the next few years for its elegant cherry and rose petal notes and silky tannins. Hints of scorched earth and dry leaves add extra interest to the reasonably complex bouquet.',
#         'Applejack Vineyard', ..., nan, 'Pinot Noir', 'Giant Steps'],
#        ...,
#        ['Australia',
#         'Deep cassis aromas, a touch of licorice, and menthol notes on the nose open to a palate of black-currant and cocoa flavors in this well-balanced, medium-weight wine. Nicely structured, it finishes with good length and moderate tannins; can be cellared a few years. Best Buy.',
#         nan, ..., nan, 'Cabernet Sauvignon', "Jacob's Creek"],
#        ['Australia',
# 3822    T Series Chardonnay-Pinot Noir-Pinot Meunier      89   13.0
# 3934                              Keyneton Euphonium      94   65.0
# 3935                                   The Signature      94   55.0
# 3958                                      The Struie      94   50.0
# 4232                           The Octavius Old Vine      93  120.0
# 4477                           The Octavius Old Vine      93  120.0
# ...                                              ...     ...    ...
# 149441                                Western Branch      85   20.0
# 149520                                           NaN      85   35.0
# 149535                                         White      85   10.0
# 149536                                           NaN      85    5.0
# 149543                                           NaN      85   13.0
# 149544                                Central Ranges      85   15.0
# 149548                                           NaN      84   17.0
# 149612                                       Reserve      84   13.0
# 149614                                        Bin 65      84    8.0
# 149621                                      Zeepaard      84   10.0
# 149632                                           NaN      84   12.0
# 149639                                           NaN      84    8.0
# 150434                              Herzog Selection      85   12.0
# 150468                                           NaN      85   12.0
# 150562                                        Grange      96  185.0
# 150563                                           RWT      95   70.0
# 150570                                       Bin 707      93   90.0
# 150571                                      Yattarna      92   65.0
# 150597                                       Bin 407      90   19.0
# 150607                                       Bin 128      90   22.0
# 150621                                       Bin 389      89   19.0
# 150634                                       Reserve      88   18.0
# 150650                                 Koonunga Hill      87   15.0
# 150768                               Limited Release      92   50.0
# 150779                                       Reserve      91   18.0
# 150786                               Limited Release      90   38.0
# 150801                                       Reserve      88   16.0
# 150810                                           NaN      88   11.0
# 150819                                           NaN      87   10.0
# 150854                                           NaN      85    8.0
#
#                  province                 region_1 region_2  \
# 61               Victoria     Mornington Peninsula      NaN
# 631       South Australia           Adelaide Hills      NaN
# 660              Victoria             Yarra Valley      NaN
# 825       South Australia             McLaren Vale      NaN
# 987              Tasmania                 Tasmania      NaN
# 1066      South Australia              Eden Valley      NaN
# 2025      South Australia           Barossa Valley      NaN
# 2028             Victoria           Nagambie Lakes      NaN
# 2148      South Australia           Barossa Valley      NaN
# 2325      South Australia           Adelaide Hills      NaN
# 2379      South Australia             McLaren Vale      NaN
# 2398             Victoria           Nagambie Lakes      NaN
# 2458      South Australia             McLaren Vale      NaN
# 2617             Victoria             Yarra Valley      NaN
# 2703             Victoria           Nagambie Lakes      NaN
# 2973      South Australia           Adelaide Hills      NaN
# 2992             Victoria                 Victoria      NaN
# 3033      South Australia          South Australia      NaN
# 3044      South Australia              Eden Valley      NaN
# 3047      South Australia          Langhorne Creek      NaN
# 3048      South Australia           Barossa Valley      NaN
# 3324             Victoria                 Victoria      NaN
# 3584      South Australia           Barossa Valley      NaN
# 3655      South Australia           Barossa Valley      NaN
# 3822      Australia Other                Australia      NaN
# 3934      South Australia                  Barossa      NaN
# 3935      South Australia                  Barossa      NaN
# 3958      South Australia                  Barossa      NaN
# 4232      South Australia                  Barossa      NaN
# 4477      South Australia                  Barossa      NaN
# ...                   ...                      ...      ...
# 149441    South Australia                 Lenswood      NaN
# 149520           Victoria                Heathcote      NaN
# 149535    South Australia             McLaren Vale      NaN
# 149536    Australia Other  South Eastern Australia      NaN
# 149543    South Australia           Adelaide Hills      NaN
# 149544    New South Wales          New South Wales      NaN
# 150571                 Chardonnay            Penfolds
# 150597         Cabernet Sauvignon            Penfolds
# 150607                     Shiraz            Penfolds
# 150621         Cabernet Sauvignon            Penfolds
# 150634                   Riesling            Penfolds
# 150650  Shiraz-Cabernet Sauvignon            Penfolds
# 150768  Shiraz-Cabernet Sauvignon       Jacob's Creek
# 150779                     Shiraz       Jacob's Creek
# 150786                 Chardonnay       Jacob's Creek
# 150801                 Chardonnay       Jacob's Creek
# 150810         Cabernet Sauvignon       Jacob's Creek
# 150819                 Chardonnay       Jacob's Creek
# 150854        Semillon-Chardonnay       Jacob's Creek
#
# [4957 rows x 10 columns]

# %%
len(df_Aus[df_Aus.price.isnull()])
# Out:
# 0

# %%
df_Aus.province.value_counts()
# Out:
# South Australia      3004
# Victoria              613
# Australia Other       553
# Western Australia     491
# New South Wales       246
# Tasmania               47
# Queensland              3
# Name: province, dtype: int64

# %%
varieties = list(df_Aus.variety.unique())

# %%
colors = viridis(len(varieties))

# %%
color_map = dict(zip(varieties, colors))

# %%
df_Aus["variety_color"] = df_Aus["variety"].map(color_map)

# %%
df_Aus.head()
# Out:
#        country                                        description  \
# 61   Australia  Moorooduc's estate Pinot Noir is a solid value...
# 631  Australia  Tim Knappstein's decision to focus on the Adel...
# 660  Australia  This crisp, delicate Pinot Noir should be cons...
# 825  Australia  The Dead Arm is always firmly structured, maki...
# 987  Australia  This is strongly marked by new oak on the nose...
#
#                        designation  points  price         province  \
# 61                             NaN      91   36.0         Victoria
# 631                     The Dagger      90   20.0  South Australia
# 660             Applejack Vineyard      88   42.0         Victoria
# 825                   The Dead Arm      90   65.0  South Australia
# 987  Coal River Valley Single Site      90   65.0         Tasmania
#
#                  region_1 region_2     variety       winery variety_color
# 61   Mornington Peninsula      NaN  Pinot Noir    Moorooduc       #440154
# 631        Adelaide Hills      NaN  Pinot Noir      Riposte       #440154
# 660          Yarra Valley      NaN  Pinot Noir  Giant Steps       #440154
# 825          McLaren Vale      NaN      Shiraz   D'Arenberg       #450558
# 987              Tasmania      NaN  Pinot Noir    Dalrymple       #440154

# %%
df_Aus.to_csv("/Users/liying/Downloads/Aussie_Wines_Plotting.csv")

# %%
import pandas as pd
from bokeh.plotting import figure
from bokeh.layouts import layout, widgetbox
from bokeh.models import ColumnDataSource, HoverTool, BoxZoomTool, ResetTool, PanTool
from bokeh.models.widgets import Slider, Select, TextInput, Div
from bokeh.models import WheelZoomTool, SaveTool, LassoSelectTool
from bokeh.io import curdoc
from functools import lru_cache

@lru_cache()
def load_data():
    df = pd.read_csv("/Users/liying/Downloads/Aussie_Wines_Plotting.csv", index_col=0)
    return df

# %%
""" Interactive Wine Visualization Tool
See pbpython.com for the associated blog post explaining the process and
goals of this script
"""

import pandas as pd
from bokeh.plotting import figure
from bokeh.layouts import layout, widgetbox
from bokeh.models import ColumnDataSource, HoverTool, BoxZoomTool, ResetTool, PanTool
from bokeh.models.widgets import Slider, Select, TextInput, Div
from bokeh.models import WheelZoomTool, SaveTool, LassoSelectTool
from bokeh.io import curdoc
from functools import lru_cache


# Define a cached function to read in the CSV file and return a dataframe
@lru_cache()
def load_data():
    df = pd.read_csv("/Users/liying/Downloads/Aussie_Wines_Plotting.csv", index_col=0)
    return df

# Column order for displaying the details of a specific review
col_order = ['price', 'points', 'variety', 'province', 'description']

all_provinces = [
    "All", "South Australia", "Victoria", "Western Australia",
    "Australia Other", "New South Wales", "Tasmania"
]

# Setup the display portions including widgets as well as text and HTML
desc = Div(text="All Provinces", width=800)
province = Select(title="Province", options=all_provinces, value="All")
price_max = Slider(start=0, end=900, step=5, value=200, title="Maximum Price")
title = TextInput(title="Title Contains")
details = Div(text='Selection Details:', width=800)

# Populate the data with the dataframe
source = ColumnDataSource(data=load_data())

# Build out the hover tools
hover = HoverTool(tooltips=[
    ("title", "@title"),
    ("variety", "@variety"),
])

# Define the tool list as a list of the objects so it is easier to customize
# each object
TOOLS = [
    hover, BoxZoomTool(), LassoSelectTool(), WheelZoomTool(), PanTool(),
    ResetTool(), SaveTool()
]

# Build out the figure with the individual circle plots
p = figure(
    plot_height=600,
    plot_width=700,
    title="Australian Wine Analysis",
    tools=TOOLS,
    x_axis_label="points",
    y_axis_label="price (USD)",
    toolbar_location='above')

p.circle(
    y="price",
    x='points',
    source=source,
    color='variety_color',
    size=7,
    alpha=0.4)


# Define the functions to update the data based on a selection or change

def select_reviews():
    """ Use the current selections to determine which filters to apply to the
    data. Return a dataframe of the selected data
    """
    df = load_data()

    # Determine what has been selected for each widgetd
    max_price = price_max.value
    province_val = province.value
    title_val = title.value

    # Filter by price and province
    if province_val == "All":
        selected = df[df.price <= max_price]
    else:
        selected = df[(df.province == province_val) & (df.price <= max_price)]

    # Further filter by string in title if it is provided
    if title_val != "":
        selected = selected[selected.title.str.contains(title_val) == True]

    # Example showing how to update the description
    desc.text = "Province: {} and Price < {}".format(province_val, max_price)
    return selected


def update():
    """ Get the selected data and update the data in the source
    """
    df_active = select_reviews()
    source.data = ColumnDataSource(data=df_active).data


def selection_change(attrname, old, new):
    """ Function will be called when the poly select (or other selection tool)
    is used. Determine which items are selected and show the details below
    the graph
    """
    selected = source.selected['1d']['indices']

    # Need to get a list of the active reviews so the indices will match up
    df_active = select_reviews()

    # If something is selected, then get those details and format the results
    # as an HTML table
    if selected:
        data = df_active.iloc[selected, :]
        temp = data.set_index('title').T.reindex(index=col_order)
        details.text = temp.style.render()
    else:
        details.text = "Selection Details"


# Setup functions for each control so that changes will be captured and data
# updated as required
controls = [province, price_max, title]

for control in controls:
    control.on_change('value', lambda attr, old, new: update())

# If the source is changed to a selection, execute that selection process
source.on_change('selected', selection_change)

# The final portion is to layout the parts and get the server going

# Build a box for all the controls
inputs = widgetbox(*controls, sizing_mode='fixed')

# Define a simple layout
l = layout([[desc], [inputs, p], [details]], sizing_mode='fixed')

# Update the data and instantiate the service
update()
curdoc().add_root(l)

# Show the title in the browser bar
curdoc().title = "Australian Wine Analysis"
